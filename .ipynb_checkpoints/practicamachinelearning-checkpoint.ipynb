# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

import numpy as np

# %%
df = pd.read_csv("C:/Users/jesus/Desktop/curso IA/Top-Películas.csv")
df
# Out:
#      indice_global  indice_estricto                    título  \
# 0                0              0.0  The Shawshank Redemption
# 1                1              1.0             The Godfather
# 2                2              1.0             The Godfather
# 3                3              2.0           The Dark Knight
# 4                4              2.0           The Dark Knight
# ...            ...              ...                       ...
# 2527          2527            998.0         The Invisible Man
# 2528          2528            998.0         The Invisible Man
# 2529          2529            999.0                  Cell 211
# 2530          2530            999.0                  Cell 211
# 2531          2531            999.0                  Cell 211
#
#                   director     año  duración           género  rating  \
# 0           Frank Darabont  1994.0     142.0            Drama     9.3
# 1     Francis Ford Coppola  1972.0     175.0           Crimen     9.2
# ...

# %%
df.isnull().sum()
# Out:
# indice_global       0
# indice_estricto    43
# título             43
# director           43
# año                43
# duración           43
# género             43
# rating             43
# metascore          43
# recaudación(M)     43
# dtype: int64

# %%
df['rating'] = df['rating'].fillna(0)

# %%
df['rating']
# Out:
# 0       9.3
# 1       9.2
# 2       9.2
# 3       9.0
# 4       9.0
#        ...
# 2527    7.6
# 2528    7.6
# 2529    7.6
# 2530    7.6
# 2531    7.6
# Name: rating, Length: 2532, dtype: float64

# %%
df.isnull().sum()
# Out:
# indice_global       0
# indice_estricto    43
# título             43
# director           43
# año                43
# duración           43
# género             43
# rating              0
# metascore          43
# recaudación(M)     43
# dtype: int64

# %%
df['recaudación(M)'] = df['recaudación(M)'].fillna(0)

# %%
plt.scatter( df['rating'], df['recaudación(M)'] )

# %%
X = df[['rating']]

# %%
y = df['recaudación(M)']

# %%
modelo = LinearRegression()

# %%
modelo.fit(X,y)
# Out:
# LinearRegression()

# %%
plt.scatter( df['rating'], df['recaudación(M)']  )
plt.plot( df['rating'], modelo.predict(X) );

# %%
# MercadodeValoresEspaña

df = pd.read_csv("C:/Users/jesus/Desktop/curso IA/MercadodeValoresEspaña.csv")
df
# Out:
#      Ticker       Fecha  Cierre  Referencia  Volumen     Rotacion  Ultimo  \
# 0       ANA  02/01/2019   74.80       73.90   156300  11621188.98   74.80
# 1       ANA  03/01/2019   76.34       74.80   140331  10632703.64   76.34
# 2       ANA  04/01/2019   76.62       76.34   130309  10010838.76   76.62
# 3       ANA  07/01/2019   77.14       76.62    63349   4855724.92   77.14
# 4       ANA  08/01/2019   78.24       77.14    99300   7749464.70   78.24
# ...     ...         ...     ...         ...      ...          ...     ...
# 8570    VIS  09/12/2019   48.70       48.76    40236   1958325.66   48.70
# 8571    VIS  10/12/2019   48.16       48.70    60198   2895965.78   48.16
# 8572    VIS  11/12/2019   47.96       48.16    63000   3012462.12   47.96
# 8573    VIS  12/12/2019   48.42       47.96    50218   2429199.80   48.42
# 8574    VIS  13/12/2019   48.64       48.42    62427   3038685.10   48.64
#
#        Alto   Bajo  Promedio
# 0     75.16  72.38   74.3518
# ...

# %%
df['Promedio'].mean()
# Out:
# np.float64(22.83744164431487)

# %%
df.isnull().sum()
# Out:
# Ticker        0
# Fecha         0
# Cierre        0
# Referencia    0
# Volumen       0
# Rotacion      0
# Ultimo        0
# Alto          0
# Bajo          0
# Promedio      0
# dtype: int64

# %%
promedio = df['Promedio'].mean()
df['Mayor_Promedio'] = np.where(df['Promedio'] >= promedio, 1, 0)
df
# Out:
#      Ticker       Fecha  Cierre  Referencia  Volumen     Rotacion  Ultimo  \
# 0       ANA  02/01/2019   74.80       73.90   156300  11621188.98   74.80
# 1       ANA  03/01/2019   76.34       74.80   140331  10632703.64   76.34
# 2       ANA  04/01/2019   76.62       76.34   130309  10010838.76   76.62
# 3       ANA  07/01/2019   77.14       76.62    63349   4855724.92   77.14
# 4       ANA  08/01/2019   78.24       77.14    99300   7749464.70   78.24
# ...     ...         ...     ...         ...      ...          ...     ...
# 8570    VIS  09/12/2019   48.70       48.76    40236   1958325.66   48.70
# 8571    VIS  10/12/2019   48.16       48.70    60198   2895965.78   48.16
# 8572    VIS  11/12/2019   47.96       48.16    63000   3012462.12   47.96
# 8573    VIS  12/12/2019   48.42       47.96    50218   2429199.80   48.42
# 8574    VIS  13/12/2019   48.64       48.42    62427   3038685.10   48.64
#
#        Alto   Bajo  Promedio  Mayor_Promedio
# ...

# %%
plt.scatter( df['Rotacion'], df['Mayor_Promedio']  );

# %%
X_entrena, X_prueba, Y_entrena, Y_prueba = train_test_split(  df[['Rotacion']],  df['Mayor_Promedio'], train_size=0.9 )

# %%
modelo = LogisticRegression()

# %%
modelo.fit(X_entrena, Y_entrena)
# Out:
# LogisticRegression()

# %%
modelo.score(X_entrena, Y_entrena)
# Out:
# 0.671504470649216

# %%
df['Rotacion'].mean() / 2
# Out:
# np.float64(24108172.219866473)

# %%
df['Rotacion'] = df['Rotacion'] +  24108172

# %%
nuevos_datos = df[['Rotacion']]

# %%
nuevos_datos
# Out:
#          Rotacion
# 0     35729360.98
# 1     34740875.64
# 2     34119010.76
# 3     28963896.92
# 4     31857636.70
# ...           ...
# 8570  26066497.66
# 8571  27004137.78
# 8572  27120634.12
# 8573  26537371.80
# 8574  27146857.10
#
# [8575 rows x 1 columns]

# %%
probabilidades = modelo.predict_proba( nuevos_datos )
probabilidades
# Out:
# array([[0.55064612, 0.44935388],
#        [0.54925416, 0.45074584],
#        [0.54837807, 0.45162193],
#        ...,
#        [0.53849924, 0.46150076],
#        [0.53767444, 0.46232556],
#        [0.53853632, 0.46146368]])

# %%
prob_mayorP = probabilidades[:,1]
prob_mayorP
# Out:
# array([0.44935388, 0.45074584, 0.45162193, ..., 0.46150076, 0.46232556,
#        0.46146368])
