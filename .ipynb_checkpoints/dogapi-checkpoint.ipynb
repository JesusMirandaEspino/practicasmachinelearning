# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
api_key = ""

# %%
url = "https://api.thecatapi.com/v1/breeds"

# %%
resp = requests.get(url)
resp
# Out:
# <Response [200]>

# %%
data = resp.json()

# %%
df = pd.DataFrame( data )
df.head()
# Out:
#                                         weight    id                name  \
# 0  {'imperial': '7  -  10', 'metric': '3 - 5'}  abys          Abyssinian
# 1    {'imperial': '7 - 10', 'metric': '3 - 5'}  aege              Aegean
# 2    {'imperial': '7 - 16', 'metric': '3 - 7'}  abob    American Bobtail
# 3    {'imperial': '5 - 10', 'metric': '2 - 5'}  acur       American Curl
# 4    {'imperial': '8 - 15', 'metric': '4 - 7'}  asho  American Shorthair
#
#                                              cfa_url  \
# 0     http://cfa.org/Breeds/BreedsAB/Abyssinian.aspx
# 1                                                NaN
# 2  http://cfa.org/Breeds/BreedsAB/AmericanBobtail...
# 3   http://cfa.org/Breeds/BreedsAB/AmericanCurl.aspx
# 4  http://cfa.org/Breeds/BreedsAB/AmericanShortha...
#
#                                       vetstreet_url  \
# 0          http://www.vetstreet.com/cats/abyssinian
# 1          http://www.vetstreet.com/cats/aegean-cat
# 2    http://www.vetstreet.com/cats/american-bobtail
# 3       http://www.vetstreet.com/cats/american-curl
# 4  http://www.vetstreet.com/cats/american-shorthair
#
#                                     vcahospitals_url  \
# 0  https://vcahospitals.com/know-your-pet/cat-bre...
# 1                                                NaN
# 2  https://vcahospitals.com/know-your-pet/cat-bre...
# 3  https://vcahospitals.com/know-your-pet/cat-bre...
# 4  https://vcahospitals.com/know-your-pet/cat-bre...
#
#                                          temperament         origin  \
# 0  Active, Energetic, Independent, Intelligent, G...          Egypt
# 1  Affectionate, Social, Intelligent, Playful, Ac...         Greece
# 2  Intelligent, Interactive, Lively, Playful, Sen...  United States
# 3  Affectionate, Curious, Intelligent, Interactiv...  United States
# 4         Active, Curious, Easy Going, Playful, Calm  United States
#
#   country_codes country_code  ... natural rare  rex  suppressed_tail  \
# 0            EG           EG  ...       1    0    0                0
# 1            GR           GR  ...       0    0    0                0
# 2            US           US  ...       0    0    0                1
# 3            US           US  ...       0    0    0                0
# 4            US           US  ...       1    0    0                0
#
#   short_legs                                     wikipedia_url  \
# 0          0    https://en.wikipedia.org/wiki/Abyssinian_(cat)
# 1          0          https://en.wikipedia.org/wiki/Aegean_cat
# 2          0    https://en.wikipedia.org/wiki/American_Bobtail
# 3          0       https://en.wikipedia.org/wiki/American_Curl
# 4          0  https://en.wikipedia.org/wiki/American_Shorthair
#
#    hypoallergenic  reference_image_id  cat_friendly  bidability
# 0               0           0XYvRd7oD           NaN         NaN
# 1               0           ozEvzdVM-           NaN         NaN
# 2               0           hBXicehMA           NaN         NaN
# 3               0           xnsqonbjW           NaN         NaN
# 4               0           JFPROfGtQ           NaN         NaN
#
# [5 rows x 39 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 39 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   weight              67 non-null     object
#  1   id                  67 non-null     object
#  2   name                67 non-null     object
#  3   cfa_url             43 non-null     object
#  4   vetstreet_url       50 non-null     object
#  5   vcahospitals_url    42 non-null     object
#  6   temperament         67 non-null     object
#  7   origin              67 non-null     object
#  8   country_codes       67 non-null     object
#  9   country_code        67 non-null     object
#  10  description         67 non-null     object
#  11  life_span           67 non-null     object
#  12  indoor              67 non-null     int64
#  13  lap                 47 non-null     float64
#  14  alt_names           63 non-null     object
#  15  adaptability        67 non-null     int64
#  16  affection_level     67 non-null     int64
#  17  child_friendly      67 non-null     int64
#  18  dog_friendly        67 non-null     int64
#  19  energy_level        67 non-null     int64
#  20  grooming            67 non-null     int64
#  21  health_issues       67 non-null     int64
#  22  intelligence        67 non-null     int64
#  23  shedding_level      67 non-null     int64
#  24  social_needs        67 non-null     int64
#  25  stranger_friendly   67 non-null     int64
#  26  vocalisation        67 non-null     int64
#  27  experimental        67 non-null     int64
#  28  hairless            67 non-null     int64
#  29  natural             67 non-null     int64
#  30  rare                67 non-null     int64
#  31  rex                 67 non-null     int64
#  32  suppressed_tail     67 non-null     int64
#  33  short_legs          67 non-null     int64
#  34  wikipedia_url       66 non-null     object
#  35  hypoallergenic      67 non-null     int64
#  36  reference_image_id  65 non-null     object
#  37  cat_friendly        7 non-null      float64
#  38  bidability          2 non-null      float64
# dtypes: float64(3), int64(21), object(15)
# memory usage: 20.5+ KB

# %%
numeros = []
for span in df["life_span"]:
    numero = int(span.split()[0])
    numeros.append(numero)

# %%
df.describe()
# Out:
#           indoor        lap  adaptability  affection_level  child_friendly  \
# count  67.000000  47.000000     67.000000        67.000000       67.000000
# mean    0.014925   0.978723      4.820896         4.865672        3.835821
# std     0.122169   0.145865      0.575388         0.422673        0.479805
# min     0.000000   0.000000      2.000000         3.000000        2.000000
# 25%     0.000000   1.000000      5.000000         5.000000        4.000000
# 50%     0.000000   1.000000      5.000000         5.000000        4.000000
# 75%     0.000000   1.000000      5.000000         5.000000        4.000000
# max     1.000000   1.000000      5.000000         5.000000        5.000000
#
#        dog_friendly  energy_level   grooming  health_issues  intelligence  \
# count     67.000000     67.000000  67.000000      67.000000     67.000000
# mean       4.611940      3.910448   1.895522       2.029851      4.358209
# std        0.777627      1.055022   1.129955       1.014593      0.899520
# min        2.000000      1.000000   1.000000       1.000000      3.000000
# 25%        5.000000      3.000000   1.000000       1.000000      3.000000
# 50%        5.000000      4.000000   1.000000       2.000000      5.000000
# 75%        5.000000      5.000000   3.000000       3.000000      5.000000
# max        5.000000      5.000000   5.000000       4.000000      5.000000
#
#        ...  experimental   hairless    natural       rare        rex  \
# count  ...     67.000000  67.000000  67.000000  67.000000  67.000000
# mean   ...      0.044776   0.044776   0.253731   0.059701   0.074627
# std    ...      0.208373   0.208373   0.438430   0.238721   0.264772
# min    ...      0.000000   0.000000   0.000000   0.000000   0.000000
# 25%    ...      0.000000   0.000000   0.000000   0.000000   0.000000
# 50%    ...      0.000000   0.000000   0.000000   0.000000   0.000000
# 75%    ...      0.000000   0.000000   0.500000   0.000000   0.000000
# max    ...      1.000000   1.000000   1.000000   1.000000   1.000000
#
#        suppressed_tail  short_legs  hypoallergenic  cat_friendly  bidability
# count        67.000000   67.000000       67.000000      7.000000    2.000000
# mean          0.089552    0.029851        0.223881      3.142857    3.500000
# std           0.287694    0.171460        0.419989      0.690066    0.707107
# min           0.000000    0.000000        0.000000      2.000000    3.000000
# 25%           0.000000    0.000000        0.000000      3.000000    3.250000
# 50%           0.000000    0.000000        0.000000      3.000000    3.500000
# 75%           0.000000    0.000000        0.000000      3.500000    3.750000
# max           1.000000    1.000000        1.000000      4.000000    4.000000
#
# [8 rows x 24 columns]

# %%
df["life_span"]
# Out:
# 0     14 - 15
# 1      9 - 12
# 2     11 - 15
# 3     12 - 16
# 4     15 - 17
#        ...
# 62    14 - 16
# 63    12 - 15
# 64    15 - 18
# 65    12 - 17
# 66    13 - 15
# Name: life_span, Length: 67, dtype: object

# %%
# seleccionar solo el primer número para la columna 'life_span'
numeros = []
for span in df['life_span']:
    numero = int(span.split()[0])
    numeros.append(numero)

df['life_span'] = numeros

# %%
df['life_span']
# Out:
# 0     14
# 1      9
# 2     11
# 3     12
# 4     15
#       ..
# 62    14
# 63    12
# 64    15
# 65    12
# 66    13
# Name: life_span, Length: 67, dtype: int64

# %%
columnas_interes = ['life_span', 'temperament']
df1 = df[columnas_interes]
df1.head()
# Out:
#    life_span                                        temperament
# 0         14  Active, Energetic, Independent, Intelligent, G...
# 1          9  Affectionate, Social, Intelligent, Playful, Ac...
# 2         11  Intelligent, Interactive, Lively, Playful, Sen...
# 3         12  Affectionate, Curious, Intelligent, Interactiv...
# 4         15         Active, Curious, Easy Going, Playful, Calm

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['life_span'], kde=True, bins=20)
plt.title('Distribución de la Esperanza de Vida de las Razas de Perros')
plt.xlabel('Esperanza de Vida (años)')
plt.ylabel('Frecuencia');

# %%
lista_temperamentos = df['temperament'].dropna().str.split(', ')
temperamentos = []
for sublista in lista_temperamentos:
    print(sublista)
    for temperamento in sublista:
        temperamentos.append(temperamento)

print(temperamentos)
serie_temperamentos = pd.Series(temperamentos)
conteo_temperamentos = serie_temperamentos.value_counts().head(30).reset_index()
conteo_temperamentos.columns = ['Temperamento', 'Conteo']

# Graficar los temperamentos más comunes
plt.figure(figsize=(12, 6))
sns.barplot(x='Conteo', y='Temperamento', data=conteo_temperamentos)
plt.title('Temperamentos más Comunes en las Razas de Perros')
plt.xlabel('Cantidad')
plt.ylabel('Temperamento');
# Out:
# ['Active', 'Energetic', 'Independent', 'Intelligent', 'Gentle']
# ['Affectionate', 'Social', 'Intelligent', 'Playful', 'Active']
# ['Intelligent', 'Interactive', 'Lively', 'Playful', 'Sensitive']
# ['Affectionate', 'Curious', 'Intelligent', 'Interactive', 'Lively', 'Playful', 'Social']
# ['Active', 'Curious', 'Easy Going', 'Playful', 'Calm']
# ['Affectionate', 'Curious', 'Gentle', 'Intelligent', 'Interactive', 'Lively', 'Loyal', 'Playful', 'Sensible', 'Social']
# ['Affectionate', 'Agile', 'Curious', 'Independent', 'Playful', 'Loyal']
# ['Lively', 'Social', 'Fun-loving', 'Relaxed', 'Affectionate']
# ['Affectionate', 'Intelligent', 'Playful']
# ['Affectionate', 'Lively', 'Friendly', 'Intelligent']
# ['Alert', 'Agile', 'Energetic', 'Demanding', 'Intelligent']
# ['Affectionate', 'Active', 'Gentle', 'Social']
# ['Affectionate', 'Dependent', 'Gentle', 'Intelligent', 'Playful']
# ['Affectionate', 'Easy Going', 'Independent', 'Intelligent', 'Loyal', 'Social']
# ['Affectionate', 'Easy Going', 'Gentle', 'Loyal', 'Patient', 'calm']
# ['Curious', 'Intelligent', 'Gentle', 'Social', 'Interactive', 'Playful', 'Lively']
# ['Easy Going', 'Friendly', 'Intelligent', 'Lively', 'Playful', 'Social']
# ['Affectionate', 'Curious', 'Intelligent', 'Loyal', 'Social']
# ['Affectionate', 'Demanding', 'Interactive', 'Loyal']
# ['Affectionate', 'Loyal', 'Intelligent', 'Social', 'Lively', 'Playful']
# ['Affectionate', 'Intelligent', 'Playful', 'Social']
# ['Affectionate', 'Gentle', 'Intelligent', 'Social']
# ['Affectionate', 'Intelligent', 'Playful', 'Social']
# ['Affectionate', 'Intelligent', 'Active', 'Curious', 'Playful']
# ['Gentle', 'Loyal', 'Intelligent', 'Playful']
# ['Affectionate', 'Social']
# ['Highly interactive', 'Mischievous', 'Loyal', 'Social', 'Playful']
# ['Playful', 'affectionate', 'loyal', 'social']
# ['Intelligent', 'Friendly', 'Gentle', 'Loving', 'Loyal']
# ['Agile', 'Dependent', 'Gentle', 'Intelligent', 'Lively', 'Loyal', 'Playful']
# ['Sweet', 'Affectionate', 'Loyal']
# ['Affectionate', 'Sweet', 'Loyal', 'Quiet', 'Peaceful']
# ['Affectionate', 'Curious', 'Demanding', 'Friendly', 'Intelligent', 'Playful']
# ['Dependent', 'Gentle', 'Intelligent', 'Quiet', 'Social']
# ['Active', 'Agile', 'Clever', 'Easy Going', 'Intelligent', 'Lively', 'Loyal', 'Playful', 'Social']
# ['Active', 'Devoted', 'Intelligent', 'Playful']
# ['Calm', 'Relaxed', 'Talkative', 'Playful', 'Warm']
# ['Active', 'Loyal', 'highly intelligent', 'Expressive', 'Trainable']
# ['Independent', 'highly intelligent', 'clever', 'inquisitive', 'sociable', 'playful', 'trainable']
# ['Affectionate', 'Friendly', 'Gentle', 'Intelligent', 'Playful', 'Quiet']
# ['Adaptable', 'Intelligent', 'Loving', 'Gentle', 'Independent']
# ['Affectionate', 'Interactive', 'Playful', 'Social']
# ['Easy Going', 'Intelligent', 'Loyal', 'Playful', 'Social']
# ['Agile', 'Easy Going', 'Intelligent', 'Playful']
# ['Gentle', 'Quiet', 'Shy', 'Playful']
# ['Sweet', 'Active', 'Intelligent', 'Social', 'Playful', 'Lively', 'Curious']
# ['Active', 'Agile', 'Curious', 'Demanding', 'Friendly', 'Gentle', 'Lively', 'Playful', 'Social']
# ['Energetic', 'Affectionate', 'Intelligent', 'Social', 'Playful', 'Curious']
# ['Affectionate', 'loyal', 'Sedate', 'Quiet']
# ['Affectionate', 'Social', 'Intelligent', 'Loyal']
# ['Affectionate', 'Friendly', 'Gentle', 'Calm']
# ['Affectionate', 'Friendly', 'Gentle', 'Quiet', 'Easygoing']
# ['Active', 'Dependent', 'Easy Going', 'Gentle', 'Intelligent', 'Loyal', 'Playful', 'Quiet']
# ['Curious', 'Social', 'Intelligent', 'Loyal', 'Outgoing', 'Adventurous', 'Affectionate']
# ['Affectionate', 'Intelligent', 'Loyal', 'Playful', 'Social', 'Sweet', 'Loving']
# ['Active', 'Affectionate', 'Dependent', 'Gentle', 'Patient', 'Playful', 'Quiet', 'Social']
# ['Active', 'Agile', 'Clever', 'Sociable', 'Loving', 'Energetic']
# ['Curious', 'Intelligent', 'Loyal', 'Sweet', 'Agile', 'Playful', 'Affectionate']
# ['Affectionate', 'Curious', 'Easy Going', 'Intelligent', 'Interactive', 'Lively', 'Loyal']
# ['Affectionate', 'Social', 'Intelligent', 'Sweet-tempered']
# ['Mischievous', 'Tenacious', 'Intelligent', 'Affectionate', 'Gentle', 'Interactive', 'Loyal']
# ['Loyal', 'Inquisitive', 'Friendly', 'Quiet', 'Gentle']
# ['Curious', 'Intelligent', 'Social', 'Lively', 'Outgoing', 'Playful', 'Affectionate']
# ['Playful', 'Social', 'Intelligent']
# ['Affectionate', 'Agile', 'Clever', 'Gentle', 'Intelligent', 'Playful', 'Social']
# ['Agile', 'Intelligent', 'Loyal', 'Playful', 'Energetic']
# ['Playful', 'Social', 'Intelligent', 'Curious', 'Friendly']
# ['Active', 'Energetic', 'Independent', 'Intelligent', 'Gentle', 'Affectionate', 'Social', 'Intelligent', 'Playful', 'Active', 'Intelligent', 'Interactive', 'Lively', 'Playful', 'Sensitive', 'Affectionate', 'Curious', 'Intelligent', 'Interactive', 'Lively', 'Playful', 'Social', 'Active', 'Curious', 'Easy Going', 'Playful', 'Calm', 'Affectionate', 'Curious', 'Gentle', 'Intelligent', 'Interactive', 'Lively', 'Loyal', 'Playful', 'Sensible', 'Social', 'Affectionate', 'Agile', 'Curious', 'Independent', 'Playful', 'Loyal', 'Lively', 'Social', 'Fun-loving', 'Relaxed', 'Affectionate', 'Affectionate', 'Intelligent', 'Playful', 'Affectionate', 'Lively', 'Friendly', 'Intelligent', 'Alert', 'Agile', 'Energetic', 'Demanding', 'Intelligent', 'Affectionate', 'Active', 'Gentle', 'Social', 'Affectionate', 'Dependent', 'Gentle', 'Intelligent', 'Playful', 'Affectionate', 'Easy Going', 'Independent', 'Intelligent', 'Loyal', 'Social', 'Affectionate', 'Easy Going', 'Gentle', 'Loyal', 'Patient', 'calm', 'Curious', 'Intelligent', 'Gentle', 'Social', 'Interactive', 'Playful', 'Lively', 'Easy Going', 'Friendly', 'Intelligent', 'Lively', 'Playful', 'Social', 'Affectionate', 'Curious', 'Intelligent', 'Loyal', 'Social', 'Affectionate', 'Demanding', 'Interactive', 'Loyal', 'Affectionate', 'Loyal', 'Intelligent', 'Social', 'Lively', 'Playful', 'Affectionate', 'Intelligent', 'Playful', 'Social', 'Affectionate', 'Gentle', 'Intelligent', 'Social', 'Affectionate', 'Intelligent', 'Playful', 'Social', 'Affectionate', 'Intelligent', 'Active', 'Curious', 'Playful', 'Gentle', 'Loyal', 'Intelligent', 'Playful', 'Affectionate', 'Social', 'Highly interactive', 'Mischievous', 'Loyal', 'Social', 'Playful', 'Playful', 'affectionate', 'loyal', 'social', 'Intelligent', 'Friendly', 'Gentle', 'Loving', 'Loyal', 'Agile', 'Dependent', 'Gentle', 'Intelligent', 'Lively', 'Loyal', 'Playful', 'Sweet', 'Affectionate', 'Loyal', 'Affectionate', 'Sweet', 'Loyal', 'Quiet', 'Peaceful', 'Affectionate', 'Curious', 'Demanding', 'Friendly', 'Intelligent', 'Playful', 'Dependent', 'Gentle', 'Intelligent', 'Quiet', 'Social', 'Active', 'Agile', 'Clever', 'Easy Going', 'Intelligent', 'Lively', 'Loyal', 'Playful', 'Social', 'Active', 'Devoted', 'Intelligent', 'Playful', 'Calm', 'Relaxed', 'Talkative', 'Playful', 'Warm', 'Active', 'Loyal', 'highly intelligent', 'Expressive', 'Trainable', 'Independent', 'highly intelligent', 'clever', 'inquisitive', 'sociable', 'playful', 'trainable', 'Affectionate', 'Friendly', 'Gentle', 'Intelligent', 'Playful', 'Quiet', 'Adaptable', 'Intelligent', 'Loving', 'Gentle', 'Independent', 'Affectionate', 'Interactive', 'Playful', 'Social', 'Easy Going', 'Intelligent', 'Loyal', 'Playful', 'Social', 'Agile', 'Easy Going', 'Intelligent', 'Playful', 'Gentle', 'Quiet', 'Shy', 'Playful', 'Sweet', 'Active', 'Intelligent', 'Social', 'Playful', 'Lively', 'Curious', 'Active', 'Agile', 'Curious', 'Demanding', 'Friendly', 'Gentle', 'Lively', 'Playful', 'Social', 'Energetic', 'Affectionate', 'Intelligent', 'Social', 'Playful', 'Curious', 'Affectionate', 'loyal', 'Sedate', 'Quiet', 'Affectionate', 'Social', 'Intelligent', 'Loyal', 'Affectionate', 'Friendly', 'Gentle', 'Calm', 'Affectionate', 'Friendly', 'Gentle', 'Quiet', 'Easygoing', 'Active', 'Dependent', 'Easy Going', 'Gentle', 'Intelligent', 'Loyal', 'Playful', 'Quiet', 'Curious', 'Social', 'Intelligent', 'Loyal', 'Outgoing', 'Adventurous', 'Affectionate', 'Affectionate', 'Intelligent', 'Loyal', 'Playful', 'Social', 'Sweet', 'Loving', 'Active', 'Affectionate', 'Dependent', 'Gentle', 'Patient', 'Playful', 'Quiet', 'Social', 'Active', 'Agile', 'Clever', 'Sociable', 'Loving', 'Energetic', 'Curious', 'Intelligent', 'Loyal', 'Sweet', 'Agile', 'Playful', 'Affectionate', 'Affectionate', 'Curious', 'Easy Going', 'Intelligent', 'Interactive', 'Lively', 'Loyal', 'Affectionate', 'Social', 'Intelligent', 'Sweet-tempered', 'Mischievous', 'Tenacious', 'Intelligent', 'Affectionate', 'Gentle', 'Interactive', 'Loyal', 'Loyal', 'Inquisitive', 'Frie ...
